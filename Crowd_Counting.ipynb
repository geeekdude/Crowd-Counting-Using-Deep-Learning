# %%
import cv2
import matplotlib.pyplot as plt
import model as cnn
import torch
import numpy as np

# %%
checkpoint_path = '/content/drive/MyDrive/Mini Project/Crowd Counting using Deep Learning/part_b_scale_4_epoch_24_weights.pth'

model = cnn.CNN(checkpoint_path=checkpoint_path)
model.cuda()
model.eval();

# %%
image = cv2.imread('/content/crowd.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
dot_map, image_out = model.head_detection(image)

# %%
plt.figure(figsize=(18,10))
plt.imshow(image_out)
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.imshow(dot_map)
plt.show()

# %%
dot_map.sum()
# Out:
# 1233.0
